# %% [markdown]
# # Topic Modelling Article Titles with BERTopic

# %% [markdown]
# Parts of our notebook:
# * Data Load
# * Preprocessing
# * Clustering
# * Modelling

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import time
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from bertopic import BERTopic

# %% [markdown]
# ## Data Load

# %%
df_titles = pd.read_csv(r"./../../data/raw/JPTIIK_unlabeled.csv")

# %%
print(df_titles.head())
# Out:
#                                              article
# 0  Sistem Pengaman Kendaraan Roda Dua dengan Peng...
# 1  Implementasi Sistem Pendukung Keputusan untuk ...
# 2  Pengembangan Database E-Learning PT XYZ menggu...
# 3  Mekanisme Penyediaan Layanan pada Perangkat Sm...
# 4  Pengendalian Suhu dan Kelembapan Udara untuk B...

# %% [markdown]
# ## Preprocessing

# %%
vectorizer = TfidfVectorizer(max_features=500)
features_tfidf = vectorizer.fit_transform(df_titles['article'])

# %%
pca = PCA(n_components=2)
features_pca = pca.fit_transform(features_tfidf.toarray())

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=features_pca[:, 0], y=features_pca[:, 1], alpha=0.7)
plt.title('Visualisasi Data Judul Jurnal Setelah PCA')
plt.xlabel('PCA Komponen 1')
plt.ylabel('PCA Komponen 2')
plt.show()

# %% [markdown]
# ## Clustering

# %%
n_clusters = 3 
kmeans = KMeans(n_clusters, random_state=42, n_init=10)

# %%
cluster_labels = kmeans.fit_predict(features_pca)

# %%
df_titles["cluster"] = cluster_labels

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=features_pca[:, 0], y=features_pca[:, 1], hue=cluster_labels, palette="tab10", alpha=0.7)

centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='X', s=300, label="Centroids")

plt.title("Visualisasi Cluster dengan KMeans")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.show()

# %%
silhouette_avg = silhouette_score(features_pca, cluster_labels)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.6020395413457478

# %%
for cluster in range(n_clusters):
    df_titles[df_titles["cluster"] == cluster].to_csv(f"../../data/raw/clustered/cluster_{cluster}.csv", index=False)

# %% [markdown]
# ## Modelling

# %%
cluster_0 = pd.read_csv("../../data/raw/clustered/cluster_0.csv")
cluster_1 = pd.read_csv("../../data/raw/clustered/cluster_1.csv")
cluster_2 = pd.read_csv("../../data/raw/clustered/cluster_2.csv")

clusters = {0: cluster_0, 1: cluster_1, 2: cluster_2}

# %%
topic_models = {}
topics_per_cluster = {}

# %%
for cluster in range(n_clusters):
    print(f"\n🔍 **Analisis Topik untuk Cluster {cluster}**")
    
    cluster_data = df_titles[df_titles["cluster"] == cluster]["article"].tolist()

    topic_model = BERTopic()
    
    topics, probs = topic_model.fit_transform(cluster_data)
    
    topic_models[cluster] = topic_model
    topics_per_cluster[cluster] = topics

    print(topic_model.get_topic_info())
# Out:
# 🔍 **Analisis Topik untuk Cluster 0**
#    Topic  Count                                      Name  \
# 0     -1     35         -1_perancangan_metode_user_design
# 1      0     68  0_design_humancentered_human_perancangan
# 2      1     31       1_dan_experience_user_questionnaire
# 3      2     30      2_thinking_mobile_perancangan_design
# 4      3     22     3_thinking_design_pengguna_pengalaman
# 5      4     19               4_hcd_human_centered_design
#
#                                       Representation  \
# 0  [perancangan, metode, user, design, menggunaka...
# 1  [design, humancentered, human, perancangan, me...
# 2  [dan, experience, user, questionnaire, evaluas...
# 3  [thinking, mobile, perancangan, design, metode...
# 4  [thinking, design, pengguna, pengalaman, peran...
# 5  [hcd, human, centered, design, perancangan, an...
#
#                                  Representative_Docs
# 0  [Perancangan User Interface (UI) Sistem Inform...
# 1  [Perancangan Pengalaman Pengguna Aplikasi Huma...
# 2  [Evaluasi dan Perbaikan Pengalaman Pengguna pa...
# 3  [Perancangan User Experience Aplikasi Berbasis...
# 4  [Perancangan Pengalaman Pengguna pada Aplikasi...
# 5  [Perancangan User Experience Sistem Informasi ...
#
# 🔍 **Analisis Topik untuk Cluster 1**
#     Topic  Count                                               Name  \
# 0      -1    271               -1_dan_pada_menggunakan_implementasi
# 1       0    100                   0_monitoring_fuzzy_sistem_sensor
# 2       1     59                            1_kursi_roda_pintar_tx2
# 3       2     54              2_learning_belajar_hasil_pembelajaran
# 4       3     42                  3_vector_support_machine_sentimen
# 5       4     39                     4_bayes_nave_naive_berdasarkan
# 6       5     38            5_usability_evaluasi_testing_eksperimen
# 7       6     33                6_convolutional_neural_network_deep
# 8       7     31          7_knearest_neighbor_neighbors_klasifikasi
# 9       8     29                    8_media_pembelajaran_smk_sosial
# 10      9     27                      9_forest_random_decision_tree
# 11     10     27               10_informasi_teknologi_platform_guru
# 12     11     27                   11_routing_protokol_network_load
# 13     12     25         12_yang_faktorfaktor_mempengaruhi_analisis
# 14     13     24                     13_webqual_40_kualitas_website
# 15     14     24              14_library_rest_performa_perbandingan
# 16     15     24                      15_memory_long_shortterm_term
# 17     16     23                   16_wearable_mpu6050_angkat_beban
# 18     17     23  17_electrocardiogram_shimmer_kelelahan_monitoring
# 19     18     21                    18_pi_raspberry_yolov8_berbasis
# 20     19     18                    19_game_gim_aesthetics_dynamics
# 21     20     17                       20_robot_beroda_humanoid_pid
# 22     21     16          21_kmeans_clustering_pelanggan_segmentasi
# 23     22     16                        22_shopping_live_beli_minat
# 24     23     15                        23_model_addie_emodul_curve
# 25     24     15                   24_acceptance_technology_use_tam
# 26     25     14              25_reality_augmented_eye_pembelajaran
# 27     26     13                  26_transform_cepstral_wavelet_mel
# 28     27     13                    27_transfer_power_wireless_daya
# 29     28     12             28_latent_twitter_dirichlet_allocation
# 30     29     11                    29_root_cause_analysis_sentimen
# 31     30     11                30_flipped_classroom_negeri_belajar
# 32     31     11               31_extreme_boosting_gradient_machine
# 33     32     10                 32_speech_parkinson_voice_penyakit
#
#                                        Representation  \
# 0   [dan, pada, menggunakan, implementasi, analisi...
# 1   [monitoring, fuzzy, sistem, sensor, air, berba...
# 2   [kursi, roda, pintar, tx2, kepala, kendali, be...
# 3   [learning, belajar, hasil, pembelajaran, based...
# 4   [vector, support, machine, sentimen, svm, ulas...
# 5   [bayes, nave, naive, berdasarkan, sentimen, kl...
# 6   [usability, evaluasi, testing, eksperimen, heu...
# 7   [convolutional, neural, network, deep, cnn, kl...
# 8   [knearest, neighbor, neighbors, klasifikasi, m...
# 9   [media, pembelajaran, smk, sosial, digital, ma...
# 10  [forest, random, decision, tree, ph, konsumsi,...
# 11  [informasi, teknologi, platform, guru, khusus,...
# 12  [routing, protokol, network, load, ad, balanci...
# 13  [yang, faktorfaktor, mempengaruhi, analisis, m...
# 14  [webqual, 40, kualitas, website, search, ipa, ...
# 15  [library, rest, performa, perbandingan, aplika...
# 16  [memory, long, shortterm, term, longshort, lst...
# 17  [wearable, mpu6050, angkat, beban, otot, train...
# 18  [electrocardiogram, shimmer, kelelahan, monito...
# 19  [pi, raspberry, yolov8, berbasis, deteksi, per...
# 20  [game, gim, aesthetics, dynamics, mechanics, f...
# 21  [robot, beroda, humanoid, pid, pengatur, bola,...
# 22  [kmeans, clustering, pelanggan, segmentasi, pe...
# 23  [shopping, live, beli, minat, pengaruh, stream...
# 24  [model, addie, emodul, curve, ux, tkj, penggun...
# 25  [acceptance, technology, use, tam, model, of, ...
# 26  [reality, augmented, eye, pembelajaran, tracki...
# 27  [transform, cepstral, wavelet, mel, pengenalan...
# 28  [transfer, power, wireless, daya, frekuensi, r...
# 29  [latent, twitter, dirichlet, allocation, topik...
# 30  [root, cause, analysis, sentimen, rca, ulasan,...
# 31  [flipped, classroom, negeri, belajar, smk, pel...
# 32  [extreme, boosting, gradient, machine, learnin...
# 33  [speech, parkinson, voice, penyakit, pattern, ...
#
#                                   Representative_Docs
# 0   [Hubungan Lingkungan Sekolah dan Motivasi Bela...
# 1   [Implementasi Protokol AODV menggunakan ESP-No...
# 2   [Deteksi Plat Nama Ruangan untuk Kendali Kursi...
# 3   [Pengaruh Implementasi Penggunaan Media Pembel...
# 4   [Analisis Sentimen Data Ulasan Aplikasi Pegada...
# 5   [Sistem Klasifikasi Air Mineral Layak Minum be...
# 6   [Evaluasi Usability pada Aplikasi Discord di I...
# 7   [Klasifikasi Terumbu Karang Menggunakan Metode...
# 8   [Sistem Klasifikasi Kualitas Air Kolam Ikan Le...
# 9   [Pengaruh Penggunaan Media Pembelajaran Intera...
# 10  [Klasifikasi Kelayakan Konsumsi Susu Kambing E...
# 11  [Analisis Perbedaan Kemampuan Menulis Argument...
# 12  [Analisis Pengaruh Node Density pada Vehicular...
# 13  [Analisis Faktor-Faktor Yang Memengaruhi Pener...
# 14  [Pengaruh Kualitas Layanan Website Terhadap Ke...
# 15  [Analisis Performa State Management Library Re...
# 16  [Analisis Sentimen Ulasan Pengguna Aplikasi Sh...
# 17  [Sistem Bantu Wearable pada Latihan Angkat Beb...
# 18  [Sistem Monitoring Target Heart Rate Pada Akti...
# 19  [Sistem Deteksi Tingkat Engagement pada Video ...
# 20  [Evaluasi Playtesting pada Gim Valorant dengan...
# 21  [Sistem Keseimbangan Berjalan Robot Humanoid m...
# 22  [Strategi Peningkatan SDM Berdasarkan Pengelom...
# 23  [Eksplorasi Pengaruh Live Shopping terhadap Mi...
# 24  [Analisis Pengalaman Pengguna pada Aplikasi Mi...
# 25  [Analisis Faktor yang Memengaruhi Perilaku Pen...
# 26  [Implementasi Augmented Reality Dalam Bidang F...
# 27  [Penerapan Transformasi STFT (Short Time Fouri...
# 28  [Perangkat Lunak Otomasi Simulasi Penerimaan D...
# 29  [Pemodelan Topik Risiko Bunuh Diri Berdasarkan...
# 30  [Root Cause Analysis Berdasarkan Ulasan Penggu...
# 31  [Pengaruh Pembelajaran Flipped Classroom terha...
# 32  [Klasifikasi Performa Pelajar dalam Proses Pem...
# 33  [Sistem Deteksi Dini Penyakit Parkinson Melalu...
#
# 🔍 **Analisis Topik untuk Cluster 2**
#    Topic  Count                                       Name  \
# 0     -1      5  -1_pembuatan_dashboard_perancangan_sistem
# 1      0    195   0_sistem_pengembangan_informasi_berbasis
# 2      1     67   1_android_aplikasi_berbasis_pengembangan
# 3      2     20  2_monitoring_pengembangan_internet_things
#
#                                       Representation  \
# 0  [pembuatan, dashboard, perancangan, sistem, da...
# 1  [sistem, pengembangan, informasi, berbasis, st...
# 2  [android, aplikasi, berbasis, pengembangan, mo...
# 3  [monitoring, pengembangan, internet, things, o...
#
#                                  Representative_Docs
# 0  [Pembuatan Sistem Informasi Pariwisata Kabupat...
# 1  [Pengembangan Sistem Informasi Manajemen Inven...
# 2  [Pengembangan Aplikasi Perangkat Bergerak Pand...
# 3  [Pengembangan Dashboard Monitoring Kinerja pad...

# %%
for cluster in range(n_clusters):
    topic_model = topic_models[cluster]
    fig = topic_model.visualize_barchart(top_n_topics=3)
    
    print(f"Menampilkan Cluster {cluster}")
    fig.show()
    
    time.sleep(2)
# Out:
# Menampilkan Cluster 0
# Menampilkan Cluster 1
# Menampilkan Cluster 2
